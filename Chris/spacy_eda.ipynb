# %%
import json, time, re, nltk, hdbscan, spacy, string
import psycopg2 as pg2
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

from sys import getsizeof
from datetime import datetime
from nltk.tokenize import RegexpTokenizer
from nltk.stem import WordNetLemmatizer
from psycopg2.extras import RealDictCursor, Json
from spacy.lang.en.examples import sentences

from sklearn.feature_extraction.text import CountVectorizer, TfidfVectorizer
from sklearn.feature_extraction.stop_words import ENGLISH_STOP_WORDS
from sklearn.decomposition import TruncatedSVD
from sklearn.metrics.pairwise import cosine_similarity
from sklearn.cluster import KMeans

np.random.seed(42)

# %matplotlib inline
sns.set_context('poster')
sns.set_style('white')
sns.set_color_codes()
plot_kwds = {'alpha' : 0.5, 's' : 80, 'linewidths':0}

# %%
def filename_format_log(file_path, 
                        logfile = 'assets/file_log.txt', 
                        now = round(time.time()), 
                        file_description = None): 
   
    try:
        ext = re.search('(?<!^)(?<!\.)\.(?!\.)', file_path).start() 
    except:
        raise NameError('Please enter a relative path with a file extension.') 
    
    stamp = re.search('(?<!^)(?<!\.)[a-z]+_[a-z]+(?=\.)', file_path).start()
    formatted_name = f'{file_path[:stamp]}{now}_{file_path[stamp:]}'  
    if not file_description:
        file_description = f'Word list saved at: {time.asctime(time.gmtime(now))}'
    with open(logfile, 'a+') as f:
        f.write(f'{formatted_name}: {file_description}\n')
    return formatted_name, now, file_description

# %%
# !ls 'assets/'
# Out:
# 1547416339_crisislex_df.csv    file_log.txt
# 1547416339_crisislex_tfidf.csv

# %% [markdown]
# Reading in the csv to format as a dataframe.

# %%
df = pd.read_csv('assets/1547416339_crisislex_df.csv', low_memory=False)

# %%
df.head()
# Out:
#                tweet id                                              tweet  \
# 0  '262596552399396864'  I've got enough candles to supply a Mexican fa...
# 1  '263044104500420609'  Sandy be soooo mad that she be shattering our ...
# 2  '263309629973491712'  @ibexgirl thankfully Hurricane Waugh played it...
# 3  '263422851133079552'  @taos you never got that magnificent case of B...
# 4  '262404311223504896'  I'm at Mad River Bar &amp; Grille (New York, N...
#
#   label       type                                          processed  \
# 0     0  hurricane  i've got enough candles to supply a mexican fa...
# 1     1  hurricane  sandy be soooo mad that she be shattering our ...
# 2     0  hurricane  ibexgirl thankfully hurricane waugh played it ...
# 3     0  hurricane  taos you never got that magnificent case of bu...
# 4     0  hurricane  i'm at mad river bar &amp; grille (new york, n...
#
#                                      clean_processed  \
# 0  ['i', 've', 'got', 'enough', 'candles', 'to', ...
# 1  ['sandy', 'be', 'soooo', 'mad', 'that', 'she',...
# 2  ['ibexgirl', 'thankfully', 'hurricane', 'waugh...
# 3  ['taos', 'you', 'never', 'got', 'that', 'magni...
# 4  ['i', 'm', 'at', 'mad', 'river', 'bar', 'amp',...
#
#                                 lemm_clean_processed
# 0  i ve got enough candle to supply a mexican family
# 1  sandy be soooo mad that she be shattering our ...
# 2  ibexgirl thankfully hurricane waugh played it ...
# 3  tao you never got that magnificent case of bur...
# 4    i m at mad river bar amp grille new york ny URL

# %%
df.isna().sum()
# Out:
# tweet id                0
# tweet                   1
# label                   2
# type                    2
# processed               2
# clean_processed         2
# lemm_clean_processed    3
# dtype: int64

# %%
df = df.dropna(axis = 0, inplace = False)

# %%
len(df.iloc[0]['lemm_clean_processed'])
# Out:
# 49

# %%
def add_spacy_data(dataset, feature_column):
    '''
    Grabs the verb, adverb, noun, and stop word Parts of Speech (POS) 
    tokens and pushes them into a new dataset. returns an 
    enriched dataset.
    
    Parameters:
    
    dataset (dataframe): the dataframe to parse
    feature_column (string): the column to parse in the dataset.
    
    Returns: 
    dataframe
    '''
    
    verbs = []
    nouns = []
    adverbs = []
    corpus = []
    nlp = spacy.load('en_core_web_md')
    ##
    for i in range (len(dataset)):
        if i % 1000 == 0:
            print(f"Extracting verbs and topics from record {i+1} of {len(dataset)}")
        
        tweet = dataset.iloc[i][feature_column]
        doc = nlp(tweet)
        spacy_dataframe = pd.DataFrame()
        
        for token in doc:
            if token.lemma_ == "-PRON-":
                    lemma = token.text
            else:
                lemma = token.lemma_
            row = {
                "Word": token.text,
                "Lemma": lemma,
                "PoS": token.pos_,
                "Stop Word": token.is_stop
            }
            spacy_dataframe = spacy_dataframe.append(row, ignore_index = True)
        verbs.append(" ".join(spacy_dataframe["Lemma"][spacy_dataframe["PoS"] == "VERB"].values))
        nouns.append(" ".join(spacy_dataframe["Lemma"][spacy_dataframe["PoS"] == "NOUN"].values))
        adverbs.append(" ".join(spacy_dataframe["Lemma"][spacy_dataframe["PoS"] == "ADV"].values))
        corpus_clean = " ".join(spacy_dataframe["Lemma"][spacy_dataframe["Stop Word"] == False].values)
        corpus_clean = re.sub(r'[^A-Za-z0-9]+', ' ', corpus_clean)   
        corpus.append(corpus_clean)
    dataset['Verbs'] = verbs
    dataset['Nouns'] = nouns
    dataset['Adverbs'] = adverbs
    dataset['Corpus'] = corpus
    return dataset

# %% [markdown]
# def prep_corpus(raw_string):
#     '''Single use of add_spacy_data to enable pipelining
#     data into predictions
#
#     Parameters:
#     raw_string (string): String to be parsed
#
#     Returns:
#     parsed string
#     '''
#
#     verbs = []
#     nouns = []
#     adverbs = []
#     corpus = []
#     nlp = spacy.load('en_core_web_sm')
#
#     doc = nlp(raw_string)
#     spacy_dataframe = pd.DataFrame()
#     for token in doc:
#         if token.lemma_ == "-PRON-":
#                 lemma = token.text
#         else:
#             lemma = token.lemma_
#         row = {
#             "Word": token.text,
#             "Lemma": lemma,
#             "PoS": token.pos_,
#             "Stop Word": token.is_stop
#         }
#         spacy_dataframe = spacy_dataframe.append(row, ignore_index = True)
#     verbs.append(" ".join(spacy_dataframe["Lemma"][spacy_dataframe["PoS"] == "VERB"].values))
#     nouns.append(" ".join(spacy_dataframe["Lemma"][spacy_dataframe["PoS"] == "NOUN"].values))
#     adverbs.append(" ".join(spacy_dataframe["Lemma"][spacy_dataframe["PoS"] == "ADV"].values))
#     corpus_clean = " ".join(spacy_dataframe["Lemma"][spacy_dataframe["Stop Word"] == False].values)
#     corpus_clean = re.sub(r'[^A-Za-z0-9]+', ' ', corpus_clean)
#
#     return corpus_clean

# %%
def map_popular_terms(dataset, feature_column, disaster_column):
    '''Function that counts the frequency of occurences of words in a dataset
    column. Returns a new dataset with those frequencies'''
    frequencies = pd.DataFrame()
    disaster = dataset[disaster_column].unique().tolist()
    for i in range (0, len(disaster)):
        disaster_corpus = str(dataset[disaster_column][dataset[disaster_column] == disaster[i]].tolist())
        tokens = disaster_corpus.split(" ")
        counts = Counter(tokens)
        frequencies = frequencies.append({
            "disaster": disaster[i],
            "Most Common Terms": counts.most_common(n=100)
        }, ignore_index=True)
    frequencies['disaster'] = frequencies['disaster'].astype(int)
    return frequencies

# %%
def map_common_words(dataset):
    '''Maps common words from across multiple columns in a dataset to 
    identify terms that show up in all columns. Normally used with the 
    outputs of map_popular_terms. returns the common words'''
    common_words = []
    for words in dataset['Most Common Terms'][0]:
        common_words.append(words[0])

    for i in range (0, len(dataset)):
        check_list = []
        disaster_list = dataset['Most Common Terms'][i]
        for words in disaster_list:
            check_list.append(words[0])
        common_words = [x for x in common_words if x  in check_list]
    return common_words

# %%
def get_common_frequency(term_list, frequency_list):
    '''Finds the frequency of occurence of terms in a list and then
    returns them in a new dataframe organized by year'''
    common_word_frequency_per_disaster = pd.DataFrame()
    for i in range(0, len(term_list)):
        word_frequency = []
        for j in range(0, len(frequency_list)):
            current_disaster = frequency_list['disaster'][j]
            current_disaster_terms = frequency_list['Most Common Terms'][j]
            for words in current_disaster_terms:
                    if term_list[i] in words[0]:
                        word_frequency.append(words[1])
                        #print(words[1])
                        break
        current_word = term_list[i]
        common_word_frequency_per_disaster[str(current_word)] = word_frequency
    common_word_frequency_per_disaster["disaster"] = np.arange(1970,2019)
    common_word_frequency_per_disaster = common_word_frequency_per_disaster.set_index("v")
    return common_word_frequency_per_disaster

# %%
add_spacy_data(df, 'lemm_clean_processed')
# Out:
# Extracting verbs and topics from record 1 of 40063
# Extracting verbs and topics from record 2 of 40063
# Extracting verbs and topics from record 3 of 40063
# Extracting verbs and topics from record 4 of 40063
# Extracting verbs and topics from record 5 of 40063
# Extracting verbs and topics from record 6 of 40063
# Extracting verbs and topics from record 7 of 40063
# Extracting verbs and topics from record 8 of 40063
# Extracting verbs and topics from record 9 of 40063
# Extracting verbs and topics from record 10 of 40063
# Extracting verbs and topics from record 11 of 40063
# Extracting verbs and topics from record 12 of 40063
# Extracting verbs and topics from record 13 of 40063
# Extracting verbs and topics from record 14 of 40063
# Extracting verbs and topics from record 15 of 40063
# Extracting verbs and topics from record 16 of 40063
# Extracting verbs and topics from record 17 of 40063
# Extracting verbs and topics from record 18 of 40063
# Extracting verbs and topics from record 19 of 40063
# Extracting verbs and topics from record 20 of 40063
# Extracting verbs and topics from record 21 of 40063
# Extracting verbs and topics from record 22 of 40063
# Extracting verbs and topics from record 23 of 40063
# Extracting verbs and topics from record 24 of 40063
# Extracting verbs and topics from record 25 of 40063
# Extracting verbs and topics from record 26 of 40063
# Extracting verbs and topics from record 27 of 40063
# Extracting verbs and topics from record 28 of 40063
# Extracting verbs and topics from record 29 of 40063
# Extracting verbs and topics from record 30 of 40063
# Extracting verbs and topics from record 31 of 40063
# Extracting verbs and topics from record 32 of 40063
# Extracting verbs and topics from record 33 of 40063
# Extracting verbs and topics from record 34 of 40063
# Extracting verbs and topics from record 35 of 40063
# Extracting verbs and topics from record 36 of 40063
# Extracting verbs and topics from record 37 of 40063
# Extracting verbs and topics from record 38 of 40063
# Extracting verbs and topics from record 39 of 40063
# Extracting verbs and topics from record 40 of 40063
# Extracting verbs and topics from record 41 of 40063
# Extracting verbs and topics from record 42 of 40063
# Extracting verbs and topics from record 43 of 40063
# Extracting verbs and topics from record 44 of 40063
# Extracting verbs and topics from record 45 of 40063
# Extracting verbs and topics from record 46 of 40063
# Extracting verbs and topics from record 47 of 40063
# Extracting verbs and topics from record 48 of 40063
# Extracting verbs and topics from record 49 of 40063
# Extracting verbs and topics from record 50 of 40063
# Extracting verbs and topics from record 51 of 40063
# Extracting verbs and topics from record 52 of 40063
# Extracting verbs and topics from record 53 of 40063
# Extracting verbs and topics from record 54 of 40063
# Extracting verbs and topics from record 55 of 40063
# Extracting verbs and topics from record 56 of 40063
# Extracting verbs and topics from record 57 of 40063
# Extracting verbs and topics from record 58 of 40063
# Extracting verbs and topics from record 59 of 40063
# Extracting verbs and topics from record 60 of 40063
# Extracting verbs and topics from record 61 of 40063
# Extracting verbs and topics from record 62 of 40063
# Extracting verbs and topics from record 63 of 40063
# Extracting verbs and topics from record 64 of 40063
# Extracting verbs and topics from record 65 of 40063
# Extracting verbs and topics from record 66 of 40063
# Extracting verbs and topics from record 67 of 40063
# Extracting verbs and topics from record 68 of 40063
# Extracting verbs and topics from record 69 of 40063
# Extracting verbs and topics from record 70 of 40063
# Extracting verbs and topics from record 71 of 40063
# Extracting verbs and topics from record 72 of 40063
# Extracting verbs and topics from record 73 of 40063
# Extracting verbs and topics from record 74 of 40063
# Extracting verbs and topics from record 75 of 40063
# Extracting verbs and topics from record 76 of 40063
# Extracting verbs and topics from record 77 of 40063
# Extracting verbs and topics from record 78 of 40063
# Extracting verbs and topics from record 79 of 40063
# Extracting verbs and topics from record 80 of 40063
# Extracting verbs and topics from record 81 of 40063
# Extracting verbs and topics from record 82 of 40063
# Extracting verbs and topics from record 83 of 40063
# Extracting verbs and topics from record 84 of 40063
# Extracting verbs and topics from record 85 of 40063
# Extracting verbs and topics from record 86 of 40063
# Extracting verbs and topics from record 87 of 40063
# Extracting verbs and topics from record 88 of 40063
# Extracting verbs and topics from record 89 of 40063
# Extracting verbs and topics from record 90 of 40063
# Extracting verbs and topics from record 91 of 40063
# Extracting verbs and topics from record 92 of 40063
# Extracting verbs and topics from record 93 of 40063
# Extracting verbs and topics from record 94 of 40063
# Extracting verbs and topics from record 95 of 40063
# Extracting verbs and topics from record 96 of 40063
# Extracting verbs and topics from record 97 of 40063
# Extracting verbs and topics from record 98 of 40063
# Extracting verbs and topics from record 99 of 40063
# Extracting verbs and topics from record 100 of 40063
# Extracting verbs and topics from record 101 of 40063
# Extracting verbs and topics from record 102 of 40063
# Extracting verbs and topics from record 103 of 40063
# Extracting verbs and topics from record 104 of 40063
# Extracting verbs and topics from record 105 of 40063
# Extracting verbs and topics from record 106 of 40063
# Extracting verbs and topics from record 107 of 40063
# Extracting verbs and topics from record 108 of 40063
# Extracting verbs and topics from record 109 of 40063
# Extracting verbs and topics from record 110 of 40063
# Extracting verbs and topics from record 111 of 40063
# Extracting verbs and topics from record 112 of 40063
# Extracting verbs and topics from record 113 of 40063
# Extracting verbs and topics from record 114 of 40063
# Extracting verbs and topics from record 115 of 40063
# Extracting verbs and topics from record 116 of 40063
# Extracting verbs and topics from record 117 of 40063
# Extracting verbs and topics from record 118 of 40063
# Extracting verbs and topics from record 119 of 40063
# Extracting verbs and topics from record 120 of 40063
# Extracting verbs and topics from record 121 of 40063
# Extracting verbs and topics from record 122 of 40063
# Extracting verbs and topics from record 123 of 40063
# Extracting verbs and topics from record 124 of 40063
# Extracting verbs and topics from record 125 of 40063
# Extracting verbs and topics from record 126 of 40063
# Extracting verbs and topics from record 127 of 40063
# Extracting verbs and topics from record 128 of 40063
# Extracting verbs and topics from record 129 of 40063
# Extracting verbs and topics from record 130 of 40063
# Extracting verbs and topics from record 131 of 40063
# Extracting verbs and topics from record 132 of 40063
# Extracting verbs and topics from record 133 of 40063
# Extracting verbs and topics from record 134 of 40063
# Extracting verbs and topics from record 135 of 40063
# Extracting verbs and topics from record 136 of 40063
# Extracting verbs and topics from record 137 of 40063
# Extracting verbs and topics from record 138 of 40063
# Extracting verbs and topics from record 139 of 40063
# Extracting verbs and topics from record 140 of 40063
# Extracting verbs and topics from record 141 of 40063
# Extracting verbs and topics from record 142 of 40063
# Extracting verbs and topics from record 143 of 40063
# Extracting verbs and topics from record 144 of 40063
# Extracting verbs and topics from record 145 of 40063
# Extracting verbs and topics from record 146 of 40063
# Extracting verbs and topics from record 147 of 40063
# Extracting verbs and topics from record 148 of 40063
# Extracting verbs and topics from record 149 of 40063
# Extracting verbs and topics from record 150 of 40063
# Extracting verbs and topics from record 151 of 40063
# Extracting verbs and topics from record 152 of 40063
# Extracting verbs and topics from record 153 of 40063
# Extracting verbs and topics from record 154 of 40063
# Extracting verbs and topics from record 155 of 40063
# Extracting verbs and topics from record 156 of 40063
# Extracting verbs and topics from record 157 of 40063
# Extracting verbs and topics from record 158 of 40063
# Extracting verbs and topics from record 159 of 40063
# Extracting verbs and topics from record 160 of 40063
# Extracting verbs and topics from record 161 of 40063
# Extracting verbs and topics from record 162 of 40063
# Extracting verbs and topics from record 163 of 40063
# Extracting verbs and topics from record 164 of 40063
# Extracting verbs and topics from record 165 of 40063
# Extracting verbs and topics from record 166 of 40063
# Extracting verbs and topics from record 167 of 40063
# Extracting verbs and topics from record 168 of 40063
# Extracting verbs and topics from record 169 of 40063
# Extracting verbs and topics from record 170 of 40063
# Extracting verbs and topics from record 171 of 40063
# Extracting verbs and topics from record 172 of 40063
# Extracting verbs and topics from record 173 of 40063
# Extracting verbs and topics from record 174 of 40063
# Extracting verbs and topics from record 175 of 40063
# Extracting verbs and topics from record 176 of 40063
# Extracting verbs and topics from record 177 of 40063
# Extracting verbs and topics from record 178 of 40063
# Extracting verbs and topics from record 179 of 40063
# Extracting verbs and topics from record 180 of 40063
# Extracting verbs and topics from record 181 of 40063
# Extracting verbs and topics from record 182 of 40063
# Extracting verbs and topics from record 183 of 40063
# Extracting verbs and topics from record 184 of 40063
# Extracting verbs and topics from record 185 of 40063
# Extracting verbs and topics from record 186 of 40063
# Extracting verbs and topics from record 187 of 40063
# Extracting verbs and topics from record 188 of 40063
# Extracting verbs and topics from record 189 of 40063
# Extracting verbs and topics from record 190 of 40063
# Extracting verbs and topics from record 191 of 40063
# Extracting verbs and topics from record 192 of 40063
# Extracting verbs and topics from record 193 of 40063
# Extracting verbs and topics from record 194 of 40063
# Extracting verbs and topics from record 195 of 40063
# Extracting verbs and topics from record 196 of 40063
# Extracting verbs and topics from record 197 of 40063
# Extracting verbs and topics from record 198 of 40063
# Extracting verbs and topics from record 199 of 40063
# Extracting verbs and topics from record 200 of 40063
# Extracting verbs and topics from record 201 of 40063
# Extracting verbs and topics from record 202 of 40063
# Extracting verbs and topics from record 203 of 40063
# Extracting verbs and topics from record 204 of 40063
# Extracting verbs and topics from record 205 of 40063
# Extracting verbs and topics from record 206 of 40063
# Extracting verbs and topics from record 207 of 40063
# Extracting verbs and topics from record 208 of 40063
# Extracting verbs and topics from record 209 of 40063
# Extracting verbs and topics from record 210 of 40063
# Extracting verbs and topics from record 211 of 40063
# Extracting verbs and topics from record 212 of 40063
# Extracting verbs and topics from record 213 of 40063
# Extracting verbs and topics from record 214 of 40063
# Extracting verbs and topics from record 215 of 40063
# Extracting verbs and topics from record 216 of 40063
# Extracting verbs and topics from record 217 of 40063
# Extracting verbs and topics from record 218 of 40063
# Extracting verbs and topics from record 219 of 40063
# Extracting verbs and topics from record 220 of 40063
# Extracting verbs and topics from record 221 of 40063
# Extracting verbs and topics from record 222 of 40063
# Extracting verbs and topics from record 223 of 40063
# Extracting verbs and topics from record 224 of 40063
# Extracting verbs and topics from record 225 of 40063
# Extracting verbs and topics from record 226 of 40063
# Extracting verbs and topics from record 227 of 40063
# Extracting verbs and topics from record 228 of 40063
# Extracting verbs and topics from record 229 of 40063
# Extracting verbs and topics from record 230 of 40063
# Extracting verbs and topics from record 231 of 40063
# Extracting verbs and topics from record 232 of 40063
# Extracting verbs and topics from record 233 of 40063
# Extracting verbs and topics from record 234 of 40063
# Extracting verbs and topics from record 235 of 40063
# Extracting verbs and topics from record 236 of 40063
# Extracting verbs and topics from record 237 of 40063
# Extracting verbs and topics from record 238 of 40063
# Extracting verbs and topics from record 239 of 40063
# Extracting verbs and topics from record 240 of 40063
# Extracting verbs and topics from record 241 of 40063
# Extracting verbs and topics from record 242 of 40063
# Extracting verbs and topics from record 243 of 40063
# Extracting verbs and topics from record 244 of 40063
# Extracting verbs and topics from record 245 of 40063
# Extracting verbs and topics from record 246 of 40063
# Extracting verbs and topics from record 247 of 40063
# Extracting verbs and topics from record 248 of 40063
# Extracting verbs and topics from record 249 of 40063
# Extracting verbs and topics from record 250 of 40063
# Extracting verbs and topics from record 251 of 40063
# Extracting verbs and topics from record 252 of 40063
# Extracting verbs and topics from record 253 of 40063
# Extracting verbs and topics from record 254 of 40063
# Extracting verbs and topics from record 255 of 40063
# Extracting verbs and topics from record 256 of 40063
# Extracting verbs and topics from record 257 of 40063
# Extracting verbs and topics from record 258 of 40063
# Extracting verbs and topics from record 259 of 40063
# Extracting verbs and topics from record 260 of 40063
# Extracting verbs and topics from record 261 of 40063
# Extracting verbs and topics from record 262 of 40063
# Extracting verbs and topics from record 263 of 40063
# Extracting verbs and topics from record 264 of 40063
# Extracting verbs and topics from record 265 of 40063
# Extracting verbs and topics from record 266 of 40063
# Extracting verbs and topics from record 267 of 40063
# Extracting verbs and topics from record 268 of 40063
# Extracting verbs and topics from record 269 of 40063
# Extracting verbs and topics from record 270 of 40063
# Extracting verbs and topics from record 271 of 40063
# Extracting verbs and topics from record 272 of 40063
# Extracting verbs and topics from record 273 of 40063
# Extracting verbs and topics from record 274 of 40063
# Extracting verbs and topics from record 275 of 40063
# Extracting verbs and topics from record 276 of 40063
# Extracting verbs and topics from record 277 of 40063
# Extracting verbs and topics from record 278 of 40063
# Extracting verbs and topics from record 279 of 40063
# Extracting verbs and topics from record 280 of 40063
# Extracting verbs and topics from record 281 of 40063
# Extracting verbs and topics from record 282 of 40063
# Extracting verbs and topics from record 283 of 40063
# Extracting verbs and topics from record 284 of 40063
# Extracting verbs and topics from record 285 of 40063
# Extracting verbs and topics from record 286 of 40063
# Extracting verbs and topics from record 287 of 40063
# Extracting verbs and topics from record 288 of 40063
# Extracting verbs and topics from record 289 of 40063
# Extracting verbs and topics from record 290 of 40063
# Extracting verbs and topics from record 291 of 40063
# Extracting verbs and topics from record 292 of 40063
# Extracting verbs and topics from record 293 of 40063
# Extracting verbs and topics from record 294 of 40063
# Extracting verbs and topics from record 295 of 40063
# Extracting verbs and topics from record 296 of 40063
# Extracting verbs and topics from record 297 of 40063
# Extracting verbs and topics from record 298 of 40063
# Extracting verbs and topics from record 299 of 40063
# Extracting verbs and topics from record 300 of 40063
# Extracting verbs and topics from record 301 of 40063
# Extracting verbs and topics from record 302 of 40063
# Extracting verbs and topics from record 303 of 40063
# Extracting verbs and topics from record 304 of 40063
# Extracting verbs and topics from record 305 of 40063
# Extracting verbs and topics from record 306 of 40063
# Extracting verbs and topics from record 307 of 40063
# Extracting verbs and topics from record 308 of 40063
# Extracting verbs and topics from record 309 of 40063
# Extracting verbs and topics from record 310 of 40063
# Extracting verbs and topics from record 311 of 40063
# Extracting verbs and topics from record 312 of 40063
# Extracting verbs and topics from record 313 of 40063
# Extracting verbs and topics from record 314 of 40063
# Extracting verbs and topics from record 315 of 40063
# Extracting verbs and topics from record 316 of 40063
# Extracting verbs and topics from record 317 of 40063
# Extracting verbs and topics from record 318 of 40063
# Extracting verbs and topics from record 319 of 40063
# Extracting verbs and topics from record 320 of 40063
# Extracting verbs and topics from record 321 of 40063
# Extracting verbs and topics from record 322 of 40063
# Extracting verbs and topics from record 323 of 40063
# Extracting verbs and topics from record 324 of 40063
# Extracting verbs and topics from record 325 of 40063
# Extracting verbs and topics from record 326 of 40063
# Extracting verbs and topics from record 327 of 40063
# Extracting verbs and topics from record 328 of 40063
# Extracting verbs and topics from record 329 of 40063
# Extracting verbs and topics from record 330 of 40063
# Extracting verbs and topics from record 331 of 40063
# Extracting verbs and topics from record 332 of 40063
# Extracting verbs and topics from record 333 of 40063
# Extracting verbs and topics from record 334 of 40063
# Extracting verbs and topics from record 335 of 40063
# Extracting verbs and topics from record 336 of 40063
# Extracting verbs and topics from record 337 of 40063
# Extracting verbs and topics from record 338 of 40063
# Extracting verbs and topics from record 339 of 40063
# Extracting verbs and topics from record 340 of 40063
# Extracting verbs and topics from record 341 of 40063
# Extracting verbs and topics from record 342 of 40063
# Extracting verbs and topics from record 343 of 40063
# Extracting verbs and topics from record 344 of 40063
# Extracting verbs and topics from record 345 of 40063
# Extracting verbs and topics from record 346 of 40063
# Extracting verbs and topics from record 347 of 40063
# Extracting verbs and topics from record 348 of 40063
# Extracting verbs and topics from record 349 of 40063
# Extracting verbs and topics from record 350 of 40063
# Extracting verbs and topics from record 351 of 40063
# Extracting verbs and topics from record 352 of 40063
# Extracting verbs and topics from record 353 of 40063
# Extracting verbs and topics from record 354 of 40063
# Extracting verbs and topics from record 355 of 40063
# Extracting verbs and topics from record 356 of 40063
# Extracting verbs and topics from record 357 of 40063
# Extracting verbs and topics from record 358 of 40063
# Extracting verbs and topics from record 359 of 40063
# Extracting verbs and topics from record 360 of 40063
# Extracting verbs and topics from record 361 of 40063
# Extracting verbs and topics from record 362 of 40063
# Extracting verbs and topics from record 363 of 40063
# Extracting verbs and topics from record 364 of 40063
# Extracting verbs and topics from record 365 of 40063
# Extracting verbs and topics from record 366 of 40063
# Extracting verbs and topics from record 367 of 40063
# Extracting verbs and topics from record 368 of 40063
# Extracting verbs and topics from record 369 of 40063
# Extracting verbs and topics from record 370 of 40063
# Extracting verbs and topics from record 371 of 40063
# Extracting verbs and topics from record 372 of 40063
# Extracting verbs and topics from record 373 of 40063
# Extracting verbs and topics from record 374 of 40063
# Extracting verbs and topics from record 375 of 40063
# Extracting verbs and topics from record 376 of 40063
# Extracting verbs and topics from record 377 of 40063
# Extracting verbs and topics from record 378 of 40063
# Extracting verbs and topics from record 379 of 40063
# Extracting verbs and topics from record 380 of 40063
# Extracting verbs and topics from record 381 of 40063
# Extracting verbs and topics from record 382 of 40063
# Extracting verbs and topics from record 383 of 40063
# Extracting verbs and topics from record 384 of 40063
# Extracting verbs and topics from record 385 of 40063
# Extracting verbs and topics from record 386 of 40063
# Extracting verbs and topics from record 387 of 40063
# Extracting verbs and topics from record 388 of 40063
# Extracting verbs and topics from record 389 of 40063
# Extracting verbs and topics from record 390 of 40063
# Extracting verbs and topics from record 391 of 40063
# Extracting verbs and topics from record 392 of 40063
# Extracting verbs and topics from record 393 of 40063
# Extracting verbs and topics from record 394 of 40063
# Extracting verbs and topics from record 395 of 40063
# Extracting verbs and topics from record 396 of 40063
# Extracting verbs and topics from record 397 of 40063
# Extracting verbs and topics from record 398 of 40063
# Extracting verbs and topics from record 399 of 40063
# Extracting verbs and topics from record 400 of 40063
# Extracting verbs and topics from record 401 of 40063
# Extracting verbs and topics from record 402 of 40063
# Extracting verbs and topics from record 403 of 40063
# Extracting verbs and topics from record 404 of 40063
# Extracting verbs and topics from record 405 of 40063
# Extracting verbs and topics from record 406 of 40063
# Extracting verbs and topics from record 407 of 40063
# Extracting verbs and topics from record 408 of 40063
# Extracting verbs and topics from record 409 of 40063
# Extracting verbs and topics from record 410 of 40063
# Extracting verbs and topics from record 411 of 40063
# Extracting verbs and topics from record 412 of 40063
# Extracting verbs and topics from record 413 of 40063
# Extracting verbs and topics from record 414 of 40063
# Extracting verbs and topics from record 415 of 40063
# Extracting verbs and topics from record 416 of 40063
# Extracting verbs and topics from record 417 of 40063
# Extracting verbs and topics from record 418 of 40063
# Extracting verbs and topics from record 419 of 40063
# Extracting verbs and topics from record 420 of 40063
# Extracting verbs and topics from record 421 of 40063
# Extracting verbs and topics from record 422 of 40063
# Extracting verbs and topics from record 423 of 40063
# Extracting verbs and topics from record 424 of 40063
# Extracting verbs and topics from record 425 of 40063
# Extracting verbs and topics from record 426 of 40063
# Extracting verbs and topics from record 427 of 40063
# Extracting verbs and topics from record 428 of 40063
# Extracting verbs and topics from record 429 of 40063
# Extracting verbs and topics from record 430 of 40063
# Extracting verbs and topics from record 431 of 40063
# Extracting verbs and topics from record 432 of 40063
# Extracting verbs and topics from record 433 of 40063
# Extracting verbs and topics from record 434 of 40063
# Extracting verbs and topics from record 435 of 40063
# Extracting verbs and topics from record 436 of 40063
# Extracting verbs and topics from record 437 of 40063
# Extracting verbs and topics from record 438 of 40063
# Extracting verbs and topics from record 439 of 40063
# Extracting verbs and topics from record 440 of 40063
# Extracting verbs and topics from record 441 of 40063
# Extracting verbs and topics from record 442 of 40063
# Extracting verbs and topics from record 443 of 40063
# Extracting verbs and topics from record 444 of 40063
# Extracting verbs and topics from record 445 of 40063
# Extracting verbs and topics from record 446 of 40063
# Extracting verbs and topics from record 447 of 40063
# Extracting verbs and topics from record 448 of 40063
# Extracting verbs and topics from record 449 of 40063
# Extracting verbs and topics from record 450 of 40063
# Extracting verbs and topics from record 451 of 40063
# Extracting verbs and topics from record 452 of 40063
# Extracting verbs and topics from record 453 of 40063
# Extracting verbs and topics from record 454 of 40063
# Extracting verbs and topics from record 455 of 40063
# Extracting verbs and topics from record 456 of 40063
# Extracting verbs and topics from record 457 of 40063
# Extracting verbs and topics from record 458 of 40063
# Extracting verbs and topics from record 459 of 40063
# Extracting verbs and topics from record 460 of 40063
# Extracting verbs and topics from record 461 of 40063
# Extracting verbs and topics from record 462 of 40063
# Extracting verbs and topics from record 463 of 40063
# Extracting verbs and topics from record 464 of 40063
# Extracting verbs and topics from record 465 of 40063
# Extracting verbs and topics from record 466 of 40063
# Extracting verbs and topics from record 467 of 40063
# Extracting verbs and topics from record 468 of 40063
# Extracting verbs and topics from record 469 of 40063
# Extracting verbs and topics from record 470 of 40063
# Extracting verbs and topics from record 471 of 40063
# Extracting verbs and topics from record 472 of 40063
# Extracting verbs and topics from record 473 of 40063
# Extracting verbs and topics from record 474 of 40063
# Extracting verbs and topics from record 475 of 40063
# Extracting verbs and topics from record 476 of 40063
# Extracting verbs and topics from record 477 of 40063
# Extracting verbs and topics from record 478 of 40063
# Extracting verbs and topics from record 479 of 40063
# Extracting verbs and topics from record 480 of 40063
# Extracting verbs and topics from record 481 of 40063
# Extracting verbs and topics from record 482 of 40063
# Extracting verbs and topics from record 483 of 40063
# Extracting verbs and topics from record 484 of 40063
# Extracting verbs and topics from record 485 of 40063
# Extracting verbs and topics from record 486 of 40063
# Extracting verbs and topics from record 487 of 40063
# Extracting verbs and topics from record 488 of 40063
# Extracting verbs and topics from record 489 of 40063
# Extracting verbs and topics from record 490 of 40063
# Extracting verbs and topics from record 491 of 40063
# Extracting verbs and topics from record 492 of 40063
# Extracting verbs and topics from record 493 of 40063
# Extracting verbs and topics from record 494 of 40063
# Extracting verbs and topics from record 495 of 40063
# Extracting verbs and topics from record 496 of 40063
# Extracting verbs and topics from record 497 of 40063
# Extracting verbs and topics from record 498 of 40063
# Extracting verbs and topics from record 499 of 40063
# Extracting verbs and topics from record 500 of 40063
# Extracting verbs and topics from record 501 of 40063
# Extracting verbs and topics from record 502 of 40063
# Extracting verbs and topics from record 503 of 40063
# Extracting verbs and topics from record 504 of 40063
# Extracting verbs and topics from record 505 of 40063
# Extracting verbs and topics from record 506 of 40063
# Extracting verbs and topics from record 507 of 40063
# Extracting verbs and topics from record 508 of 40063
# Extracting verbs and topics from record 509 of 40063
# Extracting verbs and topics from record 510 of 40063
# Extracting verbs and topics from record 511 of 40063
# Extracting verbs and topics from record 512 of 40063
# Extracting verbs and topics from record 513 of 40063
# Extracting verbs and topics from record 514 of 40063
# Extracting verbs and topics from record 515 of 40063
# Extracting verbs and topics from record 516 of 40063
# Extracting verbs and topics from record 517 of 40063
# Extracting verbs and topics from record 518 of 40063
# Extracting verbs and topics from record 519 of 40063
# Extracting verbs and topics from record 520 of 40063
# Extracting verbs and topics from record 521 of 40063
# Extracting verbs and topics from record 522 of 40063
# Extracting verbs and topics from record 523 of 40063
# Extracting verbs and topics from record 524 of 40063
# Extracting verbs and topics from record 525 of 40063
# Extracting verbs and topics from record 526 of 40063
# Extracting verbs and topics from record 527 of 40063
# Extracting verbs and topics from record 528 of 40063
# Extracting verbs and topics from record 529 of 40063
# Extracting verbs and topics from record 530 of 40063
# Extracting verbs and topics from record 531 of 40063
# Extracting verbs and topics from record 532 of 40063
# Extracting verbs and topics from record 533 of 40063
# Extracting verbs and topics from record 534 of 40063
# Extracting verbs and topics from record 535 of 40063
# Extracting verbs and topics from record 536 of 40063
# Extracting verbs and topics from record 537 of 40063
# Extracting verbs and topics from record 538 of 40063
# Extracting verbs and topics from record 539 of 40063
# Extracting verbs and topics from record 540 of 40063
# Extracting verbs and topics from record 541 of 40063
# Extracting verbs and topics from record 542 of 40063
# Extracting verbs and topics from record 543 of 40063
# Extracting verbs and topics from record 544 of 40063
# Extracting verbs and topics from record 545 of 40063
# Extracting verbs and topics from record 546 of 40063
# Extracting verbs and topics from record 547 of 40063
# Extracting verbs and topics from record 548 of 40063
# Extracting verbs and topics from record 549 of 40063
# Extracting verbs and topics from record 550 of 40063
# Extracting verbs and topics from record 551 of 40063
# Extracting verbs and topics from record 552 of 40063
# Extracting verbs and topics from record 553 of 40063
# Extracting verbs and topics from record 554 of 40063
# Extracting verbs and topics from record 555 of 40063
# Extracting verbs and topics from record 556 of 40063
# Extracting verbs and topics from record 557 of 40063
# Extracting verbs and topics from record 558 of 40063
# Extracting verbs and topics from record 559 of 40063
# Extracting verbs and topics from record 560 of 40063
# Extracting verbs and topics from record 561 of 40063
# Extracting verbs and topics from record 562 of 40063
# Extracting verbs and topics from record 563 of 40063
# Extracting verbs and topics from record 564 of 40063
# Extracting verbs and topics from record 565 of 40063
# Extracting verbs and topics from record 566 of 40063
# Extracting verbs and topics from record 567 of 40063
# Extracting verbs and topics from record 568 of 40063
# Extracting verbs and topics from record 569 of 40063
# Extracting verbs and topics from record 570 of 40063
# Extracting verbs and topics from record 571 of 40063
# Extracting verbs and topics from record 572 of 40063
# Extracting verbs and topics from record 573 of 40063
# Extracting verbs and topics from record 574 of 40063
# Extracting verbs and topics from record 575 of 40063
# Extracting verbs and topics from record 576 of 40063
# Extracting verbs and topics from record 577 of 40063
# Extracting verbs and topics from record 578 of 40063
# Extracting verbs and topics from record 579 of 40063
# Extracting verbs and topics from record 580 of 40063
# Extracting verbs and topics from record 581 of 40063
# Extracting verbs and topics from record 582 of 40063
# Extracting verbs and topics from record 583 of 40063
# Extracting verbs and topics from record 584 of 40063
# Extracting verbs and topics from record 585 of 40063
# Extracting verbs and topics from record 586 of 40063
# Extracting verbs and topics from record 587 of 40063
# Extracting verbs and topics from record 588 of 40063
# Extracting verbs and topics from record 589 of 40063
# Extracting verbs and topics from record 590 of 40063
# Extracting verbs and topics from record 591 of 40063
# Extracting verbs and topics from record 592 of 40063
# Extracting verbs and topics from record 593 of 40063
# Extracting verbs and topics from record 594 of 40063
# Extracting verbs and topics from record 595 of 40063
# Extracting verbs and topics from record 596 of 40063
# Extracting verbs and topics from record 597 of 40063
# Extracting verbs and topics from record 598 of 40063
# Extracting verbs and topics from record 599 of 40063
# Extracting verbs and topics from record 600 of 40063
# Extracting verbs and topics from record 601 of 40063
# Extracting verbs and topics from record 602 of 40063
# Extracting verbs and topics from record 603 of 40063
# Extracting verbs and topics from record 604 of 40063
# Extracting verbs and topics from record 605 of 40063
# Extracting verbs and topics from record 606 of 40063
# Extracting verbs and topics from record 607 of 40063
# Extracting verbs and topics from record 608 of 40063
# Extracting verbs and topics from record 609 of 40063
# Extracting verbs and topics from record 610 of 40063
# Extracting verbs and topics from record 611 of 40063
# Extracting verbs and topics from record 612 of 40063
# Extracting verbs and topics from record 613 of 40063
# Extracting verbs and topics from record 614 of 40063
# Extracting verbs and topics from record 615 of 40063
# Extracting verbs and topics from record 616 of 40063
# Extracting verbs and topics from record 617 of 40063
# Extracting verbs and topics from record 618 of 40063
# Extracting verbs and topics from record 619 of 40063
# Extracting verbs and topics from record 620 of 40063
# Extracting verbs and topics from record 621 of 40063
# Extracting verbs and topics from record 622 of 40063
# Extracting verbs and topics from record 623 of 40063
# Extracting verbs and topics from record 624 of 40063
# Extracting verbs and topics from record 625 of 40063
# Extracting verbs and topics from record 626 of 40063
# Extracting verbs and topics from record 627 of 40063
# Extracting verbs and topics from record 628 of 40063
# Extracting verbs and topics from record 629 of 40063
# Extracting verbs and topics from record 630 of 40063
# Extracting verbs and topics from record 631 of 40063
# Extracting verbs and topics from record 632 of 40063
# Extracting verbs and topics from record 633 of 40063
# Extracting verbs and topics from record 634 of 40063
# Extracting verbs and topics from record 635 of 40063
# Extracting verbs and topics from record 636 of 40063
# Extracting verbs and topics from record 637 of 40063
# Extracting verbs and topics from record 638 of 40063
# Extracting verbs and topics from record 639 of 40063
# Extracting verbs and topics from record 640 of 40063
# Extracting verbs and topics from record 641 of 40063
# Extracting verbs and topics from record 642 of 40063
# Extracting verbs and topics from record 643 of 40063
# Extracting verbs and topics from record 644 of 40063
# Extracting verbs and topics from record 645 of 40063
# Extracting verbs and topics from record 646 of 40063
# Extracting verbs and topics from record 647 of 40063
# Extracting verbs and topics from record 648 of 40063
# Extracting verbs and topics from record 649 of 40063
# Extracting verbs and topics from record 650 of 40063
# Extracting verbs and topics from record 651 of 40063
# Extracting verbs and topics from record 652 of 40063
# Extracting verbs and topics from record 653 of 40063
# Extracting verbs and topics from record 654 of 40063
# Extracting verbs and topics from record 655 of 40063
# Extracting verbs and topics from record 656 of 40063
# Extracting verbs and topics from record 657 of 40063
# Extracting verbs and topics from record 658 of 40063
# Extracting verbs and topics from record 659 of 40063
# Extracting verbs and topics from record 660 of 40063
# Extracting verbs and topics from record 661 of 40063
# Extracting verbs and topics from record 662 of 40063
# Extracting verbs and topics from record 663 of 40063
# Extracting verbs and topics from record 664 of 40063
# Extracting verbs and topics from record 665 of 40063
# Extracting verbs and topics from record 666 of 40063
# Extracting verbs and topics from record 667 of 40063
# Extracting verbs and topics from record 668 of 40063
# Extracting verbs and topics from record 669 of 40063
# Extracting verbs and topics from record 670 of 40063
# Extracting verbs and topics from record 671 of 40063
# Extracting verbs and topics from record 672 of 40063
# Extracting verbs and topics from record 673 of 40063
# Extracting verbs and topics from record 674 of 40063
# Extracting verbs and topics from record 675 of 40063
# Extracting verbs and topics from record 676 of 40063
# Extracting verbs and topics from record 677 of 40063
# Extracting verbs and topics from record 678 of 40063
# Extracting verbs and topics from record 679 of 40063
# Extracting verbs and topics from record 680 of 40063
# Extracting verbs and topics from record 681 of 40063
# Extracting verbs and topics from record 682 of 40063
# Extracting verbs and topics from record 683 of 40063
# Extracting verbs and topics from record 684 of 40063
# Extracting verbs and topics from record 685 of 40063
# Extracting verbs and topics from record 686 of 40063
# Extracting verbs and topics from record 687 of 40063
# Extracting verbs and topics from record 688 of 40063
# Extracting verbs and topics from record 689 of 40063
# Extracting verbs and topics from record 690 of 40063
# Extracting verbs and topics from record 691 of 40063
# Extracting verbs and topics from record 692 of 40063
# Extracting verbs and topics from record 693 of 40063
# Extracting verbs and topics from record 694 of 40063
# Extracting verbs and topics from record 695 of 40063
# Extracting verbs and topics from record 696 of 40063
# Extracting verbs and topics from record 697 of 40063
# Extracting verbs and topics from record 698 of 40063
# Extracting verbs and topics from record 699 of 40063
# Extracting verbs and topics from record 700 of 40063
# Extracting verbs and topics from record 701 of 40063
# Extracting verbs and topics from record 702 of 40063
# Extracting verbs and topics from record 703 of 40063
# Extracting verbs and topics from record 704 of 40063
# Extracting verbs and topics from record 705 of 40063
# Extracting verbs and topics from record 706 of 40063
# Extracting verbs and topics from record 707 of 40063
# Extracting verbs and topics from record 708 of 40063
# Extracting verbs and topics from record 709 of 40063
# Extracting verbs and topics from record 710 of 40063
# Extracting verbs and topics from record 711 of 40063
# Extracting verbs and topics from record 712 of 40063
# Extracting verbs and topics from record 713 of 40063
# Extracting verbs and topics from record 714 of 40063
# Extracting verbs and topics from record 715 of 40063
# Extracting verbs and topics from record 716 of 40063
# Extracting verbs and topics from record 717 of 40063
# Extracting verbs and topics from record 718 of 40063
# Extracting verbs and topics from record 719 of 40063
# Extracting verbs and topics from record 720 of 40063
# Extracting verbs and topics from record 721 of 40063
# Extracting verbs and topics from record 722 of 40063
# Extracting verbs and topics from record 723 of 40063
# Extracting verbs and topics from record 724 of 40063
# Extracting verbs and topics from record 725 of 40063
# Extracting verbs and topics from record 726 of 40063
# Extracting verbs and topics from record 727 of 40063
# Extracting verbs and topics from record 728 of 40063
# Extracting verbs and topics from record 729 of 40063
# Extracting verbs and topics from record 730 of 40063
# Extracting verbs and topics from record 731 of 40063
# Extracting verbs and topics from record 732 of 40063
# Extracting verbs and topics from record 733 of 40063
# Extracting verbs and topics from record 734 of 40063
# Extracting verbs and topics from record 735 of 40063
# Extracting verbs and topics from record 736 of 40063
# Extracting verbs and topics from record 737 of 40063
# Extracting verbs and topics from record 738 of 40063
# Extracting verbs and topics from record 739 of 40063
# Extracting verbs and topics from record 740 of 40063
# Extracting verbs and topics from record 741 of 40063
# Extracting verbs and topics from record 742 of 40063
# Extracting verbs and topics from record 743 of 40063
# Extracting verbs and topics from record 744 of 40063
# Extracting verbs and topics from record 745 of 40063
# Extracting verbs and topics from record 746 of 40063
# Extracting verbs and topics from record 747 of 40063
# Extracting verbs and topics from record 748 of 40063
# Extracting verbs and topics from record 749 of 40063
# Extracting verbs and topics from record 750 of 40063
# Extracting verbs and topics from record 751 of 40063
# Extracting verbs and topics from record 752 of 40063
# Extracting verbs and topics from record 753 of 40063
# Extracting verbs and topics from record 754 of 40063
# Extracting verbs and topics from record 755 of 40063
# Extracting verbs and topics from record 756 of 40063
# Extracting verbs and topics from record 757 of 40063
# Extracting verbs and topics from record 758 of 40063
# Extracting verbs and topics from record 759 of 40063
# Extracting verbs and topics from record 760 of 40063
# Extracting verbs and topics from record 761 of 40063
# Extracting verbs and topics from record 762 of 40063
# Extracting verbs and topics from record 763 of 40063
# Extracting verbs and topics from record 764 of 40063
# Extracting verbs and topics from record 765 of 40063
# Extracting verbs and topics from record 766 of 40063
# Extracting verbs and topics from record 767 of 40063
# Extracting verbs and topics from record 768 of 40063
# Extracting verbs and topics from record 769 of 40063
# Extracting verbs and topics from record 770 of 40063
# Extracting verbs and topics from record 771 of 40063
# Extracting verbs and topics from record 772 of 40063
# Extracting verbs and topics from record 773 of 40063
# Extracting verbs and topics from record 774 of 40063
# Extracting verbs and topics from record 775 of 40063
# Extracting verbs and topics from record 776 of 40063
# Extracting verbs and topics from record 777 of 40063
# Extracting verbs and topics from record 778 of 40063
# Extracting verbs and topics from record 779 of 40063
# Extracting verbs and topics from record 780 of 40063
# Extracting verbs and topics from record 781 of 40063
# Extracting verbs and topics from record 782 of 40063
# Extracting verbs and topics from record 783 of 40063
# Extracting verbs and topics from record 784 of 40063
# Extracting verbs and topics from record 785 of 40063
# Extracting verbs and topics from record 786 of 40063
# Extracting verbs and topics from record 787 of 40063
# Extracting verbs and topics from record 788 of 40063
# Extracting verbs and topics from record 789 of 40063
# Extracting verbs and topics from record 790 of 40063
# Extracting verbs and topics from record 791 of 40063
# Extracting verbs and topics from record 792 of 40063
# Extracting verbs and topics from record 793 of 40063
# Extracting verbs and topics from record 794 of 40063
# Extracting verbs and topics from record 795 of 40063
# Extracting verbs and topics from record 796 of 40063
# Extracting verbs and topics from record 797 of 40063
# Extracting verbs and topics from record 798 of 40063
# Extracting verbs and topics from record 799 of 40063
# Extracting verbs and topics from record 800 of 40063
# Extracting verbs and topics from record 801 of 40063
# Extracting verbs and topics from record 802 of 40063
# Extracting verbs and topics from record 803 of 40063
# Extracting verbs and topics from record 804 of 40063
# Extracting verbs and topics from record 805 of 40063
# Extracting verbs and topics from record 806 of 40063
# Extracting verbs and topics from record 807 of 40063
# Extracting verbs and topics from record 808 of 40063
# Extracting verbs and topics from record 809 of 40063
# Extracting verbs and topics from record 810 of 40063
# Extracting verbs and topics from record 811 of 40063
# Extracting verbs and topics from record 812 of 40063
# Extracting verbs and topics from record 813 of 40063
# Extracting verbs and topics from record 814 of 40063
# Extracting verbs and topics from record 815 of 40063
# Extracting verbs and topics from record 816 of 40063
# Extracting verbs and topics from record 817 of 40063
# Extracting verbs and topics from record 818 of 40063
# Extracting verbs and topics from record 819 of 40063
# Extracting verbs and topics from record 820 of 40063
# Extracting verbs and topics from record 821 of 40063
# Extracting verbs and topics from record 822 of 40063
# Extracting verbs and topics from record 823 of 40063
# Extracting verbs and topics from record 824 of 40063
# Extracting verbs and topics from record 825 of 40063
# Extracting verbs and topics from record 826 of 40063
# Extracting verbs and topics from record 827 of 40063
# Extracting verbs and topics from record 828 of 40063
# Extracting verbs and topics from record 829 of 40063
# Extracting verbs and topics from record 830 of 40063
# Extracting verbs and topics from record 831 of 40063
# Extracting verbs and topics from record 832 of 40063
# Extracting verbs and topics from record 833 of 40063
# Extracting verbs and topics from record 834 of 40063
# Extracting verbs and topics from record 835 of 40063
# Extracting verbs and topics from record 836 of 40063
# Extracting verbs and topics from record 837 of 40063
# Extracting verbs and topics from record 838 of 40063
# Extracting verbs and topics from record 839 of 40063
# Extracting verbs and topics from record 840 of 40063
# Extracting verbs and topics from record 841 of 40063
# Extracting verbs and topics from record 842 of 40063
# Extracting verbs and topics from record 843 of 40063
# Extracting verbs and topics from record 844 of 40063
# Extracting verbs and topics from record 845 of 40063
# Extracting verbs and topics from record 846 of 40063
# Extracting verbs and topics from record 847 of 40063
# Extracting verbs and topics from record 848 of 40063
# Extracting verbs and topics from record 849 of 40063
# Extracting verbs and topics from record 850 of 40063
# Extracting verbs and topics from record 851 of 40063
# Extracting verbs and topics from record 852 of 40063
# Extracting verbs and topics from record 853 of 40063
# Extracting verbs and topics from record 854 of 40063
# Extracting verbs and topics from record 855 of 40063
# Extracting verbs and topics from record 856 of 40063
# Extracting verbs and topics from record 857 of 40063
# Extracting verbs and topics from record 858 of 40063
# Extracting verbs and topics from record 859 of 40063
# Extracting verbs and topics from record 860 of 40063
# Extracting verbs and topics from record 861 of 40063
# Extracting verbs and topics from record 862 of 40063
# Extracting verbs and topics from record 863 of 40063
# Extracting verbs and topics from record 864 of 40063
# Extracting verbs and topics from record 865 of 40063
# Extracting verbs and topics from record 866 of 40063
# Extracting verbs and topics from record 867 of 40063
# Extracting verbs and topics from record 868 of 40063
# Extracting verbs and topics from record 869 of 40063
# Extracting verbs and topics from record 870 of 40063
# Extracting verbs and topics from record 871 of 40063
# Extracting verbs and topics from record 872 of 40063
# Extracting verbs and topics from record 873 of 40063
# Extracting verbs and topics from record 874 of 40063
# Extracting verbs and topics from record 875 of 40063
# Extracting verbs and topics from record 876 of 40063
# Extracting verbs and topics from record 877 of 40063
# Extracting verbs and topics from record 878 of 40063
# Extracting verbs and topics from record 879 of 40063
# Extracting verbs and topics from record 880 of 40063
# Extracting verbs and topics from record 881 of 40063
# Extracting verbs and topics from record 882 of 40063
# Extracting verbs and topics from record 883 of 40063
# Extracting verbs and topics from record 884 of 40063
# Extracting verbs and topics from record 885 of 40063
# Extracting verbs and topics from record 886 of 40063
# Extracting verbs and topics from record 887 of 40063
# Extracting verbs and topics from record 888 of 40063
# Extracting verbs and topics from record 889 of 40063
# Extracting verbs and topics from record 890 of 40063
# Extracting verbs and topics from record 891 of 40063
# Extracting verbs and topics from record 892 of 40063
# Extracting verbs and topics from record 893 of 40063
# Extracting verbs and topics from record 894 of 40063
# Extracting verbs and topics from record 895 of 40063
# Extracting verbs and topics from record 896 of 40063
# Extracting verbs and topics from record 897 of 40063
# Extracting verbs and topics from record 898 of 40063
# Extracting verbs and topics from record 899 of 40063
# Extracting verbs and topics from record 900 of 40063
# Extracting verbs and topics from record 901 of 40063
# Extracting verbs and topics from record 902 of 40063
# Extracting verbs and topics from record 903 of 40063
# Extracting verbs and topics from record 904 of 40063
# Extracting verbs and topics from record 905 of 40063
# Extracting verbs and topics from record 906 of 40063
# Extracting verbs and topics from record 907 of 40063
# ...
# Extracting verbs and topics from record 7350 of 40063
# Extracting verbs and topics from record 7351 of 40063
# Extracting verbs and topics from record 7352 of 40063
# Extracting verbs and topics from record 7353 of 40063
# Extracting verbs and topics from record 7354 of 40063
# Extracting verbs and topics from record 7355 of 40063
# Extracting verbs and topics from record 7356 of 40063
# Extracting verbs and topics from record 7357 of 40063
# Extracting verbs and topics from record 7358 of 40063
# Extracting verbs and topics from record 7359 of 40063
# Extracting verbs and topics from record 7360 of 40063
# Extracting verbs and topics from record 7361 of 40063
# Extracting verbs and topics from record 7362 of 40063
# Extracting verbs and topics from record 7363 of 40063
# Extracting verbs and topics from record 7364 of 40063
# Extracting verbs and topics from record 7365 of 40063
# Extracting verbs and topics from record 7366 of 40063
# Extracting verbs and topics from record 7367 of 40063
# Extracting verbs and topics from record 7368 of 40063
# Extracting verbs and topics from record 7369 of 40063
# Extracting verbs and topics from record 7370 of 40063
# Extracting verbs and topics from record 7371 of 40063
# Extracting verbs and topics from record 7372 of 40063
# Extracting verbs and topics from record 7373 of 40063
# Extracting verbs and topics from record 7374 of 40063
# Extracting verbs and topics from record 7375 of 40063
# Extracting verbs and topics from record 7376 of 40063
# Extracting verbs and topics from record 7377 of 40063
# Extracting verbs and topics from record 7378 of 40063
# Extracting verbs and topics from record 7379 of 40063
# Extracting verbs and topics from record 7380 of 40063
# Extracting verbs and topics from record 7381 of 40063
# Extracting verbs and topics from record 7382 of 40063
# Extracting verbs and topics from record 7383 of 40063
# Extracting verbs and topics from record 7384 of 40063
# Extracting verbs and topics from record 7385 of 40063
# Extracting verbs and topics from record 7386 of 40063
# Extracting verbs and topics from record 7387 of 40063
# Extracting verbs and topics from record 7388 of 40063
# Extracting verbs and topics from record 7389 of 40063
# Extracting verbs and topics from record 7390 of 40063
# Extracting verbs and topics from record 7391 of 40063
# Extracting verbs and topics from record 7392 of 40063
# Extracting verbs and topics from record 7393 of 40063
# Extracting verbs and topics from record 7394 of 40063
# Extracting verbs and topics from record 7395 of 40063
# Extracting verbs and topics from record 7396 of 40063
# Extracting verbs and topics from record 7397 of 40063
# Extracting verbs and topics from record 7398 of 40063
# Extracting verbs and topics from record 7399 of 40063
# Extracting verbs and topics from record 7400 of 40063
# Extracting verbs and topics from record 7401 of 40063
# Extracting verbs and topics from record 7402 of 40063
# Extracting verbs and topics from record 7403 of 40063
# Extracting verbs and topics from record 7404 of 40063
# Extracting verbs and topics from record 7405 of 40063
# Extracting verbs and topics from record 7406 of 40063
# Extracting verbs and topics from record 7407 of 40063
# Extracting verbs and topics from record 7408 of 40063
# Extracting verbs and topics from record 7409 of 40063
# Extracting verbs and topics from record 7410 of 40063
# Extracting verbs and topics from record 7411 of 40063
# Extracting verbs and topics from record 7412 of 40063
# Extracting verbs and topics from record 7413 of 40063
# Extracting verbs and topics from record 7414 of 40063
# Extracting verbs and topics from record 7415 of 40063
# Extracting verbs and topics from record 7416 of 40063
# Extracting verbs and topics from record 7417 of 40063
# Extracting verbs and topics from record 7418 of 40063
# Extracting verbs and topics from record 7419 of 40063
# Extracting verbs and topics from record 7420 of 40063
# Extracting verbs and topics from record 7421 of 40063
# Extracting verbs and topics from record 7422 of 40063
# Extracting verbs and topics from record 7423 of 40063
# Extracting verbs and topics from record 7424 of 40063
# Extracting verbs and topics from record 7425 of 40063
# Extracting verbs and topics from record 7426 of 40063
# Extracting verbs and topics from record 7427 of 40063
# Extracting verbs and topics from record 7428 of 40063
# Extracting verbs and topics from record 7429 of 40063
# Extracting verbs and topics from record 7430 of 40063
# Extracting verbs and topics from record 7431 of 40063
# Extracting verbs and topics from record 7432 of 40063
# Extracting verbs and topics from record 7433 of 40063
# Extracting verbs and topics from record 7434 of 40063
# Extracting verbs and topics from record 7435 of 40063
# Extracting verbs and topics from record 7436 of 40063
# Extracting verbs and topics from record 7437 of 40063
# Extracting verbs and topics from record 7438 of 40063
# Extracting verbs and topics from record 7439 of 40063
# Extracting verbs and topics from record 7440 of 40063
# Extracting verbs and topics from record 7441 of 40063
# Extracting verbs and topics from record 7442 of 40063
# Extracting verbs and topics from record 7443 of 40063
# Extracting verbs and topics from record 7444 of 40063
# Extracting verbs and topics from record 7445 of 40063
# Extracting verbs and topics from record 7446 of 40063
# Extracting verbs and topics from record 7447 of 40063
# Extracting verbs and topics from record 7448 of 40063
# Extracting verbs and topics from record 7449 of 40063
# Extracting verbs and topics from record 7450 of 40063
# Extracting verbs and topics from record 7451 of 40063
# Extracting verbs and topics from record 7452 of 40063
# Extracting verbs and topics from record 7453 of 40063
# Extracting verbs and topics from record 7454 of 40063
# Extracting verbs and topics from record 7455 of 40063
# Extracting verbs and topics from record 7456 of 40063
# Extracting verbs and topics from record 7457 of 40063
# Extracting verbs and topics from record 7458 of 40063
# Extracting verbs and topics from record 7459 of 40063
# Extracting verbs and topics from record 7460 of 40063
# Extracting verbs and topics from record 7461 of 40063
# Extracting verbs and topics from record 7462 of 40063
# Extracting verbs and topics from record 7463 of 40063
# Extracting verbs and topics from record 7464 of 40063
# Extracting verbs and topics from record 7465 of 40063
# Extracting verbs and topics from record 7466 of 40063
# Extracting verbs and topics from record 7467 of 40063
# Extracting verbs and topics from record 7468 of 40063
# Extracting verbs and topics from record 7469 of 40063
# Extracting verbs and topics from record 7470 of 40063
# Extracting verbs and topics from record 7471 of 40063
# Extracting verbs and topics from record 7472 of 40063
# Extracting verbs and topics from record 7473 of 40063
# Extracting verbs and topics from record 7474 of 40063
# Extracting verbs and topics from record 7475 of 40063
# Extracting verbs and topics from record 7476 of 40063
# Extracting verbs and topics from record 7477 of 40063
# Extracting verbs and topics from record 7478 of 40063
# Extracting verbs and topics from record 7479 of 40063
# Extracting verbs and topics from record 7480 of 40063
# Extracting verbs and topics from record 7481 of 40063
# Extracting verbs and topics from record 7482 of 40063
# Extracting verbs and topics from record 7483 of 40063
# Extracting verbs and topics from record 7484 of 40063
# Extracting verbs and topics from record 7485 of 40063
# Extracting verbs and topics from record 7486 of 40063
# Extracting verbs and topics from record 7487 of 40063
# Extracting verbs and topics from record 7488 of 40063
# Extracting verbs and topics from record 7489 of 40063
# Extracting verbs and topics from record 7490 of 40063
# Extracting verbs and topics from record 7491 of 40063
# Extracting verbs and topics from record 7492 of 40063
# Extracting verbs and topics from record 7493 of 40063
# Extracting verbs and topics from record 7494 of 40063
# Extracting verbs and topics from record 7495 of 40063
# Extracting verbs and topics from record 7496 of 40063
# Extracting verbs and topics from record 7497 of 40063
# Extracting verbs and topics from record 7498 of 40063
# Extracting verbs and topics from record 7499 of 40063
# Extracting verbs and topics from record 7500 of 40063
# Extracting verbs and topics from record 7501 of 40063
# Extracting verbs and topics from record 7502 of 40063
# Extracting verbs and topics from record 7503 of 40063
# Extracting verbs and topics from record 7504 of 40063
# Extracting verbs and topics from record 7505 of 40063
# Extracting verbs and topics from record 7506 of 40063
# Extracting verbs and topics from record 7507 of 40063
# Extracting verbs and topics from record 7508 of 40063
# Extracting verbs and topics from record 7509 of 40063
# Extracting verbs and topics from record 7510 of 40063
# Extracting verbs and topics from record 7511 of 40063
# Extracting verbs and topics from record 7512 of 40063
# Extracting verbs and topics from record 7513 of 40063
# Extracting verbs and topics from record 7514 of 40063
# Extracting verbs and topics from record 7515 of 40063
# Extracting verbs and topics from record 7516 of 40063
# Extracting verbs and topics from record 7517 of 40063
# Extracting verbs and topics from record 7518 of 40063
# Extracting verbs and topics from record 7519 of 40063
# Extracting verbs and topics from record 7520 of 40063
# Extracting verbs and topics from record 7521 of 40063
# Extracting verbs and topics from record 7522 of 40063
# Extracting verbs and topics from record 7523 of 40063
# Extracting verbs and topics from record 7524 of 40063
# Extracting verbs and topics from record 7525 of 40063
# Extracting verbs and topics from record 7526 of 40063
# Extracting verbs and topics from record 7527 of 40063
# Extracting verbs and topics from record 7528 of 40063
# Extracting verbs and topics from record 7529 of 40063
# Extracting verbs and topics from record 7530 of 40063
# Extracting verbs and topics from record 7531 of 40063
# Extracting verbs and topics from record 7532 of 40063
# Extracting verbs and topics from record 7533 of 40063
# Extracting verbs and topics from record 7534 of 40063
# Extracting verbs and topics from record 7535 of 40063
# Extracting verbs and topics from record 7536 of 40063
# Extracting verbs and topics from record 7537 of 40063
# Extracting verbs and topics from record 7538 of 40063
# Extracting verbs and topics from record 7539 of 40063
# Extracting verbs and topics from record 7540 of 40063
# Extracting verbs and topics from record 7541 of 40063
# Extracting verbs and topics from record 7542 of 40063
# Extracting verbs and topics from record 7543 of 40063
# Extracting verbs and topics from record 7544 of 40063
# Extracting verbs and topics from record 7545 of 40063
# Extracting verbs and topics from record 7546 of 40063
# Extracting verbs and topics from record 7547 of 40063
# Extracting verbs and topics from record 7548 of 40063
# Extracting verbs and topics from record 7549 of 40063
# Extracting verbs and topics from record 7550 of 40063
# Extracting verbs and topics from record 7551 of 40063
# Extracting verbs and topics from record 7552 of 40063
# Extracting verbs and topics from record 7553 of 40063
# Extracting verbs and topics from record 7554 of 40063
# Extracting verbs and topics from record 7555 of 40063
# Extracting verbs and topics from record 7556 of 40063
# Extracting verbs and topics from record 7557 of 40063
# Extracting verbs and topics from record 7558 of 40063
# Extracting verbs and topics from record 7559 of 40063
# Extracting verbs and topics from record 7560 of 40063
# Extracting verbs and topics from record 7561 of 40063
# Extracting verbs and topics from record 7562 of 40063
# Extracting verbs and topics from record 7563 of 40063
# Extracting verbs and topics from record 7564 of 40063
# Extracting verbs and topics from record 7565 of 40063
# Extracting verbs and topics from record 7566 of 40063
# Extracting verbs and topics from record 7567 of 40063
# Extracting verbs and topics from record 7568 of 40063
# Extracting verbs and topics from record 7569 of 40063
# Extracting verbs and topics from record 7570 of 40063
# Extracting verbs and topics from record 7571 of 40063
# Extracting verbs and topics from record 7572 of 40063
# Extracting verbs and topics from record 7573 of 40063
# Extracting verbs and topics from record 7574 of 40063
# Extracting verbs and topics from record 7575 of 40063
# Extracting verbs and topics from record 7576 of 40063
# Extracting verbs and topics from record 7577 of 40063
# Extracting verbs and topics from record 7578 of 40063
# Extracting verbs and topics from record 7579 of 40063
# Extracting verbs and topics from record 7580 of 40063
# Extracting verbs and topics from record 7581 of 40063
# Extracting verbs and topics from record 7582 of 40063
# Extracting verbs and topics from record 7583 of 40063
# Extracting verbs and topics from record 7584 of 40063
# Extracting verbs and topics from record 7585 of 40063
# Extracting verbs and topics from record 7586 of 40063
# Extracting verbs and topics from record 7587 of 40063
# Extracting verbs and topics from record 7588 of 40063
# Extracting verbs and topics from record 7589 of 40063
# Extracting verbs and topics from record 7590 of 40063
# Extracting verbs and topics from record 7591 of 40063
# Extracting verbs and topics from record 7592 of 40063
# Extracting verbs and topics from record 7593 of 40063
# Extracting verbs and topics from record 7594 of 40063
# Extracting verbs and topics from record 7595 of 40063
# Extracting verbs and topics from record 7596 of 40063
# Extracting verbs and topics from record 7597 of 40063
# Extracting verbs and topics from record 7598 of 40063
# Extracting verbs and topics from record 7599 of 40063
# Extracting verbs and topics from record 7600 of 40063
# Extracting verbs and topics from record 7601 of 40063
# Extracting verbs and topics from record 7602 of 40063
# Extracting verbs and topics from record 7603 of 40063
# Extracting verbs and topics from record 7604 of 40063
# Extracting verbs and topics from record 7605 of 40063
# Extracting verbs and topics from record 7606 of 40063
# Extracting verbs and topics from record 7607 of 40063
# Extracting verbs and topics from record 7608 of 40063
# Extracting verbs and topics from record 7609 of 40063
# Extracting verbs and topics from record 7610 of 40063
# Extracting verbs and topics from record 7611 of 40063
# Extracting verbs and topics from record 7612 of 40063
# Extracting verbs and topics from record 7613 of 40063
# Extracting verbs and topics from record 7614 of 40063
# Extracting verbs and topics from record 7615 of 40063
# Extracting verbs and topics from record 7616 of 40063
# Extracting verbs and topics from record 7617 of 40063
# Extracting verbs and topics from record 7618 of 40063
# Extracting verbs and topics from record 7619 of 40063
# Extracting verbs and topics from record 7620 of 40063
# Extracting verbs and topics from record 7621 of 40063
# Extracting verbs and topics from record 7622 of 40063
# Extracting verbs and topics from record 7623 of 40063
# Extracting verbs and topics from record 7624 of 40063
# Extracting verbs and topics from record 7625 of 40063
# Extracting verbs and topics from record 7626 of 40063
# Extracting verbs and topics from record 7627 of 40063
# Extracting verbs and topics from record 7628 of 40063
# Extracting verbs and topics from record 7629 of 40063
# Extracting verbs and topics from record 7630 of 40063
# Extracting verbs and topics from record 7631 of 40063
# Extracting verbs and topics from record 7632 of 40063
# Extracting verbs and topics from record 7633 of 40063
# Extracting verbs and topics from record 7634 of 40063
# Extracting verbs and topics from record 7635 of 40063
# Extracting verbs and topics from record 7636 of 40063
# Extracting verbs and topics from record 7637 of 40063
# Extracting verbs and topics from record 7638 of 40063
# Extracting verbs and topics from record 7639 of 40063
# Extracting verbs and topics from record 7640 of 40063
# Extracting verbs and topics from record 7641 of 40063
# Extracting verbs and topics from record 7642 of 40063
# Extracting verbs and topics from record 7643 of 40063
# Extracting verbs and topics from record 7644 of 40063
# Extracting verbs and topics from record 7645 of 40063
