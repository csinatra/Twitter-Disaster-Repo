# %%
import twitter
import json
import time
import psycopg2 as pg2
import numpy as np
import pandas as pd

from datetime import datetime
from psycopg2.extras import RealDictCursor, Json

# %%
# %run sql_test.py

# %%
def con_cur_to_db(dbname=DBNAME, dict_cur=None):
    ''' 
    Returns both a connection and a cursor object for your database
    '''

    con = pg2.connect(host=IP_ADDRESS, #allows you to navigate db
                  dbname=dbname,
                  user=USER,
                  password=PASSWORD)
    if dict_cur:
        cur = con.cursor(cursor_factory=RealDictCursor)
    else:
        cur = con.cursor()
    return con, cur
    
def execute_query(query, dbname=DBNAME, dict_cur=None, command=False):
    '''
    Executes a query directly to a database, without having to create a cursor and connection each time. 
    '''
    con, cur = con_cur_to_db(dbname, dict_cur)
    cur.execute(f'{query}')
    if not command:
        data = cur.fetchall()
        con.close()
        return data
    con.commit() #sends to server
    con.close() #closes server connection

def insert_entry_json(data, tablename=None):
    con, cur = con_cur_to_db()
    for x in data:
        cur.execute(f'INSERT INTO {tablename} (data) VALUES ({Json(x)});')
    con.commit()
    con.close()

# %%
twitter_keys = {
    'consumer_key':        'OoTmt8ytXol9yRJxLvBbYER5e',
    'consumer_secret':     'wHEGZ4juW2AIUU1GFp32oA8vGtre8Se5hSPp5DfOmeNJ2a3Ld7',
    'access_token_key':    '1080874755215872001-9F7ZdDBK2b9hgBKjSTiTQXIWY2XdyM',
    'access_token_secret': 'HIMPWRosWf2Wlu73wEPWjsmjobO3FvtRaa3MneDW0wT3q'
}

api = twitter.Api(
    consumer_key         =   twitter_keys['consumer_key'],
    consumer_secret      =   twitter_keys['consumer_secret'],
    access_token_key     =   twitter_keys['access_token_key'],
    access_token_secret  =   twitter_keys['access_token_secret'],
#     sleep_on_rate_limit=True
)

# %%
results = api.GetSearch(
            geocode='35.2271,-80.8431,2mi',
            term = 'timberlake%20justin%20concert%20show%' 
            return_json = True
        )
# Out:
#   File "<ipython-input-22-03915e22e584>", line 4
#     return_json = True
#               ^
# SyntaxError: invalid syntax

# %%
results['statuses'][0]
# Out:
# {'created_at': 'Mon Jan 07 13:36:58 +0000 2019',
#  'id': 1082269865375920128,
#  'id_str': '1082269865375920128',
#  'text': 'My article on Maori Davenport and the unreasonable ruling of Steve Savarese. Savarese’s comments are revealing, and… https://t.co/Klko7QAn0f',
#  'truncated': True,
#  'entities': {'hashtags': [],
#   'symbols': [],
#   'user_mentions': [],
#   'urls': [{'url': 'https://t.co/Klko7QAn0f',
#     'expanded_url': 'https://twitter.com/i/web/status/1082269865375920128',
#     'display_url': 'twitter.com/i/web/status/1…',
#     'indices': [117, 140]}]},
#  'metadata': {'result_type': 'popular', 'iso_language_code': 'en'},
#  'source': '<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>',
#  'in_reply_to_status_id': None,
#  'in_reply_to_status_id_str': None,
#  'in_reply_to_user_id': None,
#  'in_reply_to_user_id_str': None,
#  'in_reply_to_screen_name': None,
#  'user': {'id': 40892016,
#   'id_str': '40892016',
#   'name': 'Jay Bilas',
#   'screen_name': 'JayBilas',
#   'location': '',
#   'description': 'ESPN, President, Hair Club for Men. All opinions expressed here are mine, and should be adopted by you immediately. https://t.co/KdS4BJSNPr',
#   'url': 'https://t.co/CD0TilLGS4',
#   'entities': {'url': {'urls': [{'url': 'https://t.co/CD0TilLGS4',
#       'expanded_url': 'http://www.jaybilascamp.com',
#       'display_url': 'jaybilascamp.com',
#       'indices': [0, 23]}]},
#    'description': {'urls': [{'url': 'https://t.co/KdS4BJSNPr',
#       'expanded_url': 'http://instagram.com/realdealjaybilas',
#       'display_url': 'instagram.com/realdealjaybil…',
#       'indices': [116, 139]}]}},
#   'protected': False,
#   'followers_count': 1946837,
#   'friends_count': 0,
#   'listed_count': 9297,
#   'created_at': 'Mon May 18 15:13:01 +0000 2009',
#   'favourites_count': 40,
#   'utc_offset': None,
#   'time_zone': None,
#   'geo_enabled': True,
#   'verified': True,
#   'statuses_count': 50272,
#   'lang': 'en',
#   'contributors_enabled': False,
#   'is_translator': False,
#   'is_translation_enabled': True,
#   'profile_background_color': '111D2D',
#   'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#   'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#   'profile_background_tile': False,
#   'profile_image_url': 'http://pbs.twimg.com/profile_images/3785724771/a2f9f50b4a02f9094430292888716a57_normal.png',
#   'profile_image_url_https': 'https://pbs.twimg.com/profile_images/3785724771/a2f9f50b4a02f9094430292888716a57_normal.png',
#   'profile_banner_url': 'https://pbs.twimg.com/profile_banners/40892016/1446912800',
#   'profile_link_color': '4C7599',
#   'profile_sidebar_border_color': 'FFFFFF',
#   'profile_sidebar_fill_color': '000000',
#   'profile_text_color': '878787',
#   'profile_use_background_image': True,
#   'has_extended_profile': False,
#   'default_profile': False,
#   'default_profile_image': False,
#   'following': False,
#   'follow_request_sent': False,
#   'notifications': False,
#   'translator_type': 'none'},
#  'geo': None,
#  'coordinates': None,
#  'place': {'id': '512a8a4a4c4b4be0',
#   'url': 'https://api.twitter.com/1.1/geo/id/512a8a4a4c4b4be0.json',
#   'place_type': 'city',
#   'name': 'Charlotte',
#   'full_name': 'Charlotte, NC',
#   'country_code': 'US',
#   'country': 'United States',
#   'contained_within': [],
#   'bounding_box': {'type': 'Polygon',
#    'coordinates': [[[-81.046876, 35.001706],
#      [-80.646695, 35.001706],
#      [-80.646695, 35.416412],
#      [-81.046876, 35.416412]]]},
#   'attributes': {}},
#  'contributors': None,
#  'is_quote_status': False,
#  'retweet_count': 1328,
#  'favorite_count': 3745,
#  'favorited': False,
#  'retweeted': False,
#  'possibly_sensitive': False,
#  'lang': 'en'}

# %%
def streamTweets(city, geocode, before, count, sql_db):
    for i in range(1,8):
        year, month, day = before.split('-')
        day = int(day)
        day-=1
        day = str(day).zfill(2)
        date = year + month + day
        after = datetime.strptime(date, '%Y%m%d').strftime('%Y-%m-%d')
        
        results = api.GetSearch(
            geocode=geocode,
            return_json = True
        )

        insert_entry_json(results['statuses'], sql_db)
        before = after

# %%
def tweet_repeater(city, geocode, start, repeats=100, count=100, sql_db='raw_tweets'):
    for i in range(len(repeats)):
        before = start
        
        streamTweets(city, geocode, before, count)
        time.sleep(1)
        print(f'Loop {i} complete. Raw tweets pushed to {sql_db}.')
    print('All tweets pulled.')

# %%
tweet_repeater(city='cha', geocode='35.2271,-80.8431,2mi', start='2019-01-08', repeats=100, count=100, sql_db='raw_tweets')

# %%
with open('tweets_ex.json', 'r') as f:
    raw_data = json.load(f)

# %%
raw_data[0]
# Out:
# {'created_at': 'Fri Dec 28 23:59:23 +0000 2018',
#  'id': 1078802623678038018,
#  'id_str': '1078802623678038018',
#  'text': 'RT @MitzProductions: I’ve been to a shit load of concerts this year but my top 3 in order is:\n\n1. Kung Fu Kenny\n2. Justin Timberlake\n3. Tor…',
#  'truncated': False,
#  'entities': {'hashtags': [],
#   'symbols': [],
#   'user_mentions': [{'screen_name': 'MitzProductions',
#     'name': 'Mitz Productions O1C',
#     'id': 79706752,
#     'id_str': '79706752',
#     'indices': [3, 19]}],
#   'urls': []},
#  'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#  'source': '<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>',
#  'in_reply_to_status_id': None,
#  'in_reply_to_status_id_str': None,
#  'in_reply_to_user_id': None,
#  'in_reply_to_user_id_str': None,
#  'in_reply_to_screen_name': None,
#  'user': {'id': 79706752,
#   'id_str': '79706752',
#   'name': 'Mitz Productions O1C',
#   'screen_name': 'MitzProductions',
#   'location': 'North West London',
#   'description': '1 of the coldest producers from North West LDN. Don’t follow if you’re easily offended. Search “Mitz Productions” on Spotify, Apple Music etc. #O1C #AFC',
#   'url': 'https://t.co/Kgj3XJvFWd',
#   'entities': {'url': {'urls': [{'url': 'https://t.co/Kgj3XJvFWd',
#       'expanded_url': 'https://soundcloud.com/mitzproductions',
#       'display_url': 'soundcloud.com/mitzproductions',
#       'indices': [0, 23]}]},
#    'description': {'urls': []}},
#   'protected': False,
#   'followers_count': 3543,
#   'friends_count': 582,
#   'listed_count': 57,
#   'created_at': 'Sun Oct 04 11:01:34 +0000 2009',
#   'favourites_count': 2735,
#   'utc_offset': None,
#   'time_zone': None,
#   'geo_enabled': True,
#   'verified': False,
#   'statuses_count': 104526,
#   'lang': 'en',
#   'contributors_enabled': False,
#   'is_translator': False,
#   'is_translation_enabled': False,
#   'profile_background_color': '000000',
#   'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#   'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#   'profile_background_tile': True,
#   'profile_image_url': 'http://pbs.twimg.com/profile_images/1080092557105872897/u-3M8ZoE_normal.jpg',
#   'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1080092557105872897/u-3M8ZoE_normal.jpg',
#   'profile_banner_url': 'https://pbs.twimg.com/profile_banners/79706752/1541547478',
#   'profile_link_color': '000000',
#   'profile_sidebar_border_color': '000000',
#   'profile_sidebar_fill_color': '000000',
#   'profile_text_color': '001EFF',
#   'profile_use_background_image': True,
#   'has_extended_profile': False,
#   'default_profile': False,
#   'default_profile_image': False,
#   'following': False,
#   'follow_request_sent': False,
#   'notifications': False,
#   'translator_type': 'none'},
#  'geo': None,
#  'coordinates': None,
#  'place': None,
#  'contributors': None,
#  'retweeted_status': {'created_at': 'Fri Dec 28 20:50:26 +0000 2018',
#   'id': 1078755074820763648,
#   'id_str': '1078755074820763648',
#   'text': 'I’ve been to a shit load of concerts this year but my top 3 in order is:\n\n1. Kung Fu Kenny\n2. Justin Timberlake\n3.… https://t.co/In8VT0vMjq',
#   'truncated': True,
#   'entities': {'hashtags': [],
#    'symbols': [],
#    'user_mentions': [],
#    'urls': [{'url': 'https://t.co/In8VT0vMjq',
#      'expanded_url': 'https://twitter.com/i/web/status/1078755074820763648',
#      'display_url': 'twitter.com/i/web/status/1…',
#      'indices': [116, 139]}]},
#   'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#   'source': '<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>',
#   'in_reply_to_status_id': None,
#   'in_reply_to_status_id_str': None,
#   'in_reply_to_user_id': None,
#   'in_reply_to_user_id_str': None,
#   'in_reply_to_screen_name': None,
#   'user': {'id': 79706752,
#    'id_str': '79706752',
#    'name': 'Mitz Productions O1C',
#    'screen_name': 'MitzProductions',
#    'location': 'North West London',
#    'description': '1 of the coldest producers from North West LDN. Don’t follow if you’re easily offended. Search “Mitz Productions” on Spotify, Apple Music etc. #O1C #AFC',
#    'url': 'https://t.co/Kgj3XJvFWd',
#    'entities': {'url': {'urls': [{'url': 'https://t.co/Kgj3XJvFWd',
#        'expanded_url': 'https://soundcloud.com/mitzproductions',
#        'display_url': 'soundcloud.com/mitzproductions',
#        'indices': [0, 23]}]},
#     'description': {'urls': []}},
#    'protected': False,
#    'followers_count': 3543,
#    'friends_count': 582,
#    'listed_count': 57,
#    'created_at': 'Sun Oct 04 11:01:34 +0000 2009',
#    'favourites_count': 2735,
#    'utc_offset': None,
#    'time_zone': None,
#    'geo_enabled': True,
#    'verified': False,
#    'statuses_count': 104526,
#    'lang': 'en',
#    'contributors_enabled': False,
#    'is_translator': False,
#    'is_translation_enabled': False,
#    'profile_background_color': '000000',
#    'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#    'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#    'profile_background_tile': True,
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/1080092557105872897/u-3M8ZoE_normal.jpg',
#    'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1080092557105872897/u-3M8ZoE_normal.jpg',
#    'profile_banner_url': 'https://pbs.twimg.com/profile_banners/79706752/1541547478',
#    'profile_link_color': '000000',
#    'profile_sidebar_border_color': '000000',
#    'profile_sidebar_fill_color': '000000',
#    'profile_text_color': '001EFF',
#    'profile_use_background_image': True,
#    'has_extended_profile': False,
#    'default_profile': False,
#    'default_profile_image': False,
#    'following': False,
#    'follow_request_sent': False,
#    'notifications': False,
#    'translator_type': 'none'},
#   'geo': None,
#   'coordinates': None,
#   'place': None,
#   'contributors': None,
#   'is_quote_status': False,
#   'retweet_count': 1,
#   'favorite_count': 0,
#   'favorited': False,
#   'retweeted': False,
#   'lang': 'en'},
#  'is_quote_status': False,
#  'retweet_count': 1,
#  'favorite_count': 0,
#  'favorited': False,
#  'retweeted': False,
#  'lang': 'en'}
